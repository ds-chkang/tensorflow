# %%
# 텐서플로우 버전 1. 대.
# 텐서플로우 Linear Regression Lab.
# 아래의 예제는 선형 회귀분석이며, Varaible함수를 사용하지 않고 모델 학습을 시키는 방법을 보여줍니다.

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
X = [1,2,3]
Y = [1,2,3]

# %%
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
H = X*W + b

# %%
cost = tf.reduce_mean(tf.square(H-Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
train= optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(6001):
    sess.run(train)
    if step % 100 == 0:
        print (step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 3.230237 [0.33642817] [-0.38653234]
# 100 0.0005572311 [1.0274111] [-0.06232668]
# 200 0.00034433525 [1.021552] [-0.04899276]
# 300 0.00021277876 [1.0169419] [-0.03851281]
# 400 0.00013148447 [1.0133178] [-0.03027454]
# 500 8.124917e-05 [1.010469] [-0.02379853]
# 600 5.0206017e-05 [1.0082295] [-0.01870761]
# 700 3.1023763e-05 [1.006469] [-0.0147058]
# 800 1.917075e-05 [1.0050853] [-0.01156013]
# 900 1.1846697e-05 [1.0039976] [-0.00908738]
# 1000 7.32099e-06 [1.0031425] [-0.00714366]
# 1100 4.5238125e-06 [1.0024704] [-0.00561562]
# 1200 2.7956532e-06 [1.001942] [-0.00441457]
# 1300 1.7279616e-06 [1.0015268] [-0.00347058]
# 1400 1.0680847e-06 [1.0012004] [-0.00272857]
# 1500 6.602959e-07 [1.000944] [-0.0021454]
# 1600 4.0833916e-07 [1.0007424] [-0.00168702]
# 1700 2.5257535e-07 [1.0005839] [-0.00132681]
# 1800 1.5625818e-07 [1.0004593] [-0.00104347]
# 1900 9.6662454e-08 [1.0003613] [-0.00082087]
# 2000 5.987477e-08 [1.0002842] [-0.00064604]
# 2100 3.7041456e-08 [1.0002235] [-0.00050825]
# 2200 2.2954753e-08 [1.000176] [-0.00040002]
# 2300 1.4251221e-08 [1.0001386] [-0.0003153]
# 2400 8.830269e-09 [1.0001094] [-0.00024796]
# 2500 5.4757687e-09 [1.0000857] [-0.00019557]
# 2600 3.3868692e-09 [1.0000677] [-0.0001536]
# 2700 2.1393083e-09 [1.000054] [-0.00012186]
# 2800 1.3311988e-09 [1.0000421] [-9.6338954e-05]
# 2900 7.998668e-10 [1.0000327] [-7.473966e-05]
# 3000 4.8742205e-10 [1.0000256] [-5.8398324e-05]
# 3100 3.039796e-10 [1.0000204] [-4.607494e-05]
# 3200 1.9557216e-10 [1.0000163] [-3.6759604e-05]
# 3300 1.2804506e-10 [1.0000134] [-2.9736759e-05]
# 3400 8.7743764e-11 [1.0000111] [-2.4430714e-05]
# 3500 6.100284e-11 [1.0000094] [-2.0414434e-05]
# 3600 4.4032996e-11 [1.000008] [-1.7395896e-05]
# 3700 3.3584895e-11 [1.000007] [-1.510494e-05]
# 3800 2.7628788e-11 [1.0000063] [-1.3390988e-05]
# 3900 2.2255989e-11 [1.0000057] [-1.2098397e-05]
# 4000 1.974966e-11 [1.0000054] [-1.1136706e-05]
# 4100 1.7151612e-11 [1.0000051] [-1.040869e-05]
# 4200 1.5259814e-11 [1.0000048] [-9.855445e-06]
# 4300 1.40703005e-11 [1.0000046] [-9.422351e-06]
# 4400 1.36984235e-11 [1.0000045] [-9.194471e-06]
# 4500 1.3363908e-11 [1.0000044] [-9.062327e-06]
# 4600 1.3324178e-11 [1.0000044] [-8.887895e-06]
# 4700 1.3323479e-11 [1.0000044] [-8.864762e-06]
# 4800 1.33234665e-11 [1.0000044] [-8.861693e-06]
# 4900 1.3323465e-11 [1.0000044] [-8.861287e-06]
# 5000 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5100 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5200 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5300 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5400 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5500 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5600 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5700 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5800 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 5900 1.3323465e-11 [1.0000044] [-8.861246e-06]
# 6000 1.3323465e-11 [1.0000044] [-8.861246e-06]
